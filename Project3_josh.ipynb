# %%
import pandas as pd 
import csv
import numpy as np
from pathlib import Path
import datetime as dt

# %%
data_path = Path("./Resources/Generic_Butcher_Company_2024_06.csv")
spec_path =Path("./Resources/Generic_Butcher_Company_2024_06_SPEC_SHEET.csv")

june_meat_data = pd.read_csv(data_path)
june_spec_data = pd.read_csv(spec_path)
june_meat_data.columns
# Out:
# C:\Users\The Jew\AppData\Local\Temp\ipykernel_48936\4202121077.py:4: DtypeWarning: Columns (10) have mixed types. Specify dtype option on import or set low_memory=False.
#   june_meat_data = pd.read_csv(data_path)
# Index(['Site', ' Line', ' Product', ' Date Time', ' Adaptive Length',
#        ' Caliper Length', ' Color; L', ' Diameter; Avg',
#        ' External Measurement Weight 0', ' Height; Avg', ' Max Edge Fat Width',
#        ' Single Caliper Width', ' Tail Length', ' Total Fat Percent Area',
#        ' Total Fat Top Area', '% Compliance Weight', '% Compliance Thickness'],
#       dtype='object')

# %%
june_meat_data = june_meat_data.rename(columns={
                      " Diameter; Avg":"Diameter Avg",
                      " Color; L":"Color L",
                      " Height; Avg": "Height Avg",
                      " External Measurement Weight 0":"External Measurement Weight",
                      "% Compliance Weight":"Percentage Compliance Weight",
                      "% Compliance Thickness":"Percentage Compliance Thickness",
                      ' Site':'Site',
                      ' Line':'Line',
                      ' Product':'Product',
                      ' Date Time':'Date Time',
                      ' Adaptive Length':'Adaptive Length',
                      ' Caliper Length':'Caliper Length',
                      ' Max Edge Fat Width':'Max Edge Fat Width',
                      ' Single Caliper Width':'Single Caliper Width',
                      ' Tail Length':'Tail Length',
                      ' Total Fat Percent Area':'Total Fat Percent Area',
                      ' Total Fat Top Area':'Total Fat Top Area', 
                      })

june_meat_data.columns
# Out:
# Index(['Site', 'Line', 'Product', 'Date Time', 'Adaptive Length',
#        'Caliper Length', 'Color L', 'Diameter Avg',
#        'External Measurement Weight', 'Height Avg', 'Max Edge Fat Width',
#        'Single Caliper Width', 'Tail Length', 'Total Fat Percent Area',
#        'Total Fat Top Area', 'Percentage Compliance Weight',
#        'Percentage Compliance Thickness'],
#       dtype='object')

# %%
# clean_columns = june_meat_data.columns.str.strip()
# clean_columns

# %%
# for x in range(len(june_meat_data)):
#     if june_meat_data['Line'][x]== 'NaN':
#         june_meat_data['Line'][x]="y"
# june_meat_data

# %%
for col in june_meat_data.columns:
    june_meat_data[col] = june_meat_data[col].fillna('')
    
june_meat_data
# Out:
#                           Site     Line                Product  \
# 0      Generic Butcher Company  Generic   13 oz Ribeye Tail On
# 1      Generic Butcher Company  Generic   13 oz Ribeye Tail On
# 2      Generic Butcher Company  Generic   16 oz Ribeye Tail On
# 3      Generic Butcher Company  Generic   16 oz Ribeye Tail On
# 4      Generic Butcher Company  Generic   16 oz Ribeye Tail On
# ...                        ...      ...                    ...
# 34351  Generic Butcher Company  Generic        7 oz Sirloin PO
# 34352  Generic Butcher Company  Generic        7 oz Sirloin PO
# 34353  Generic Butcher Company  Generic        7 oz Sirloin PO
# 34354  Generic Butcher Company  Generic        7 oz Sirloin PO
# 34355  Generic Butcher Company  Generic        7 oz Sirloin PO
#
#                     Date Time Adaptive Length Caliper Length Color L  \
# 0         6/3/2024 7:16:28 AM
# 1         6/3/2024 7:16:47 AM
# 2         6/3/2024 7:17:36 AM
# 3         6/3/2024 7:17:53 AM
# 4         6/3/2024 7:18:08 AM
# ...                       ...             ...            ...     ...
# 34351   6/28/2024 10:58:13 PM                        4.74138
# 34352   6/28/2024 10:58:23 PM                        4.77603
# 34353   6/28/2024 10:58:36 PM                        4.65199
# 34354   6/28/2024 10:59:01 PM                        4.46065
# 34355   6/28/2024 10:59:09 PM                        3.90196
#
#       Diameter Avg  External Measurement Weight  Height Avg  \
# 0                                         16.76     1.62952
# 1                                         16.12     1.02086
# 2                                         16.34     1.03975
# 3                                         16.16     1.05378
# 4                                         16.12     1.03522
# ...            ...                          ...         ...
# 34351                                      6.82     1.25516
# 34352                                      6.86     1.29131
# 34353                                      6.94     1.36985
# 34354                                      6.80     1.32573
# 34355                                      6.80     1.25799
#
#       Max Edge Fat Width Single Caliper Width Tail Length  \
# 0               0.513377                          1.11626
# 1               0.573745                          4.83435
# 2               0.921001                         0.936875
# 3               0.827206                          1.08492
# 4               0.959347                         0.867011
# ...                  ...                  ...         ...
# 34351                0.0              3.15575
# 34352                0.0              2.10478
# 34353                0.0              2.95081
# 34354                0.0              2.57711
# 34355                0.0              3.40737
#
#       Total Fat Percent Area Total Fat Top Area Percentage Compliance Weight  \
# 0
# 1
# 2
# 3
# 4
# ...                      ...                ...                          ...
# 34351                                         0
# 34352                                         0
# 34353                                 0.0181235
# 34354                                 0.0230846
# 34355                                 0.0221903
#
#       Percentage Compliance Thickness
# 0
# 1
# 2
# 3
# 4
# ...                               ...
# 34351
# 34352
# 34353
# 34354
# 34355
#
# [34356 rows x 17 columns]

# %%
june_meat_data = june_meat_data.replace({np.nan: None})

# %%
june_meat_data = june_meat_data.astype({"Site":str,
                                        "Line":str,
                                        "Product":str,
                                        "Date Time":str,
                                        "Adaptive Length":str,
                                        "Caliper Length":str,
                                        'Color L':str,
                                        'Diameter Avg':str,
                                        'External Measurement Weight':float,
                                        'Height Avg':float,
                                        'Max Edge Fat Width':str,
                                        'Single Caliper Width':str,
                                        'Tail Length':str,
                                        'Total Fat Percent Area':str,
                                        'Total Fat Top Area':str,
                                        'Percentage Compliance Weight':str,
                                        'Percentage Compliance Thickness':str},errors='ignore')

# %%
june_meat_data.dtypes
# Out:
# Site                                object
# Line                                object
# Product                             object
# Date Time                           object
# Adaptive Length                     object
# Caliper Length                      object
# Color L                             object
# Diameter Avg                        object
# External Measurement Weight        float64
# Height Avg                         float64
# Max Edge Fat Width                  object
# Single Caliper Width                object
# Tail Length                         object
# Total Fat Percent Area              object
# Total Fat Top Area                  object
# Percentage Compliance Weight        object
# Percentage Compliance Thickness     object
# dtype: object

# %%
# Out:
# Site                               object
#  Line                              object
#  Product                           object
#  Date Time                         object
#  Adaptive Length                   object
#  Caliper Length                    object
#  Color; L                          object
#  Diameter; Avg                     object
#  External Measurement Weight 0    float64
#  Height; Avg                      float64
#  Max Edge Fat Width                object
#  Single Caliper Width              object
#  Tail Length                       object
#  Total Fat Percent Area            object
#  Total Fat Top Area                object
# % Compliance Weight                object
# % Compliance Thickness            float64
# dtype: object
